# %%
PLINK v1.90b6.17 64-bit (28 Apr 2020)
Options in effect:
  --indep-pairwise 1000 100 0.1
  --maf 0.05
  --out LDprune_maf0.05
  --vcf greneNet_final_v1.1.recode.vcf

Hostname: memex-009.calc.carnegiescience.edu
Working directory: /carnegie/nobackup/scratch/xwu/grenet/hapFIRE_updatedVCF
Start time: Thu Aug 10 16:13:41 2023

Random number seed: 1691709221
128543 MB RAM detected; reserving 64271 MB for main workspace.
--vcf: LDprune_maf0.05-temporary.bed + LDprune_maf0.05-temporary.bim +
LDprune_maf0.05-temporary.fam written.
3235480 variants loaded from .bim file.
231 people (0 males, 0 females, 231 ambiguous) loaded from .fam.
Ambiguous sex IDs written to LDprune_maf0.05.nosex .
Using 1 thread (no multithreaded calculations invoked).
Before main variant filters, 231 founders and 0 nonfounders present.
Calculating allele frequencies... done.
2087588 variants removed due to minor allele threshold(s)
(--maf/--max-maf/--mac/--max-mac).
1147892 variants and 231 people pass filters and QC.
Note: No phenotypes present.
Pruned 294787 variants from chromosome 1, leaving 4018.
Pruned 180946 variants from chromosome 2, leaving 1896.
Pruned 204480 variants from chromosome 3, leaving 2849.
Pruned 180748 variants from chromosome 4, leaving 2594.
Pruned 272946 variants from chromosome 5, leaving 2628.
Pruning complete.  1133907 of 1147892 variants removed.
Marker lists written to LDprune_maf0.05.prune.in and LDprune_maf0.05.prune.out
.

End time: Thu Aug 10 16:14:30 2023

# %%
1147892 - 1133907
# Out:
# 13985
